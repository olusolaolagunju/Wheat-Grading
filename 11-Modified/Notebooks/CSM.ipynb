# %%
from ultralytics import YOLO

model =YOLO('/homes/olagunju/ultralytics-local/ultralytics/cfg/models/11/custom-yolo11-CSMM-SEAM.yaml')
model.info()
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# custom-YOLO11-CSMM-SEAM summary: 146 layers, 2,501,008 parameters, 2,500,992 gradients, 6.5 GFLOPs
# (146, 2501008, 2500992, 6.491967999999999)

# %%
from ultralytics import YOLO

modified_model = YOLO(
   '/homes/olagunju/ultralytics-local/ultralytics/cfg/models/11/custom-yolo11-CSMM-SEAM.yaml'
)

modified_model.train(
    data    = "/homes/olagunju/wheat_grading_project/Roboflow_data/Roboflow/550-images-dataset/data_config.yaml",
    epochs  = 400,
    imgsz   = 768,
    batch   = 16,
    seed    = 0,
    device  = "cuda:0",
    optimizer    = "SGD",
    lr0          = 0.01,
    momentum     = 0.937,
    weight_decay = 0.0005,
    conf    = 0.25,
    iou     = 0.45,
    max_det = 1500,
    cos_lr       = True,
    fliplr    = 0.5,
    flipud    = 0.0,
    degrees   = 10.0,
    translate = 0.1,
    scale     = 0.2,
    shear     = 2.0,
    hsv_h     = 0.01,
    hsv_s     = 0.1,
    hsv_v     = 0.1,
    mosaic    = 0.4,
    copy_paste = 0.0,
    project = "/homes/olagunju/wheat_grading_project/Roboflow_data/Roboflow/CLAUDE/Results",
    name    = "03-modified-CSM-yolo11"
)
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.26 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.180 🚀 Python-3.10.4 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 10823MiB)
# ...

# %%
# Load the best model from your results folder
best_model = YOLO('/homes/olagunju/wheat_grading_project/Roboflow_data/Roboflow/CLAUDE/Results/03-modified-CSM-yolo11/weights/best.pt')

# Run validation specifically to see the top metrics again
metrics = best_model.val()
print(f"Best Recall: {metrics.results_dict['metrics/recall(B)']}")
# Out:
# Ultralytics 8.3.180 🚀 Python-3.10.4 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 10823MiB)
# custom-YOLO11-CSMM-SEAM summary (fused): 87 layers, 2,463,238 parameters, 0 gradients, 6.2 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4643.1±513.2 MB/s, size: 1259.1 KB)
# val: Scanning /homes/olagunju/wheat_grading_project/Roboflow_data/Roboflow/550-images-dataset/SPLIT-DATA/val/labels.cache... 110 images, 0 backgrounds, 0 corrupt: 100%|██████████| 110/110 [00:00<?, ?it/s]
# val: /homes/olagunju/wheat_grading_project/Roboflow_data/Roboflow/550-images-dataset/SPLIT-DATA/val/images/1052454_Shruken-IMG_7216.jpg: 1 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:08<00:00,  1.22s/it]
#                    all        110       4181      0.954       0.94      0.967      0.852
#                 Stones         11        104      0.965      0.981      0.985       0.86
# ...

# %%
import torch
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
# !nvidia-smi
# Out:
# Wed Mar 25 09:18:33 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 575.51.03              Driver Version: 575.51.03      CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 2080 Ti     On  |   00000000:06:00.0 Off |                  N/A |
# | 24%   29C    P8              8W /  250W |       1MiB /  11264MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from ultralytics import YOLO

modified_model = YOLO(
   '/homes/olagunju/ultralytics-local/ultralytics/cfg/models/11/custom-yolo11-CSMM-SEAM.yaml'
)

modified_model.train(
    data    = "/homes/olagunju/wheat_grading_project/Roboflow_data/Roboflow/550-images-dataset/data_config.yaml",
    epochs  = 400,
    imgsz   = 768,
    batch   = 16,
    seed    = 0,
    device  = "cuda:0",
    optimizer    = "SGD",
    lr0          = 0.01,
    momentum     = 0.937,
    weight_decay = 0.0005,
    conf    = 0.25,
    iou     = 0.45,
    max_det = 500,
    cos_lr       = True,
    fliplr    = 0.5,
    flipud    = 0.0,
    degrees   = 10.0,
    translate = 0.1,
    scale     = 0.2,
    shear     = 2.0,
    hsv_h     = 0.01,
    hsv_s     = 0.1,
    hsv_v     = 0.1,
    mosaic    = 0.4,
    copy_paste = 0.0,
    project = "/homes/olagunju/wheat_grading_project/Roboflow_data/Roboflow/CLAUDE/Results",
    name    = "03-modified-CSM-yolo112"
)
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.27 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.180 🚀 Python-3.10.4 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 10823MiB)
# ...

# %%
# Load the best model from your results folder
best_model = YOLO('/homes/olagunju/wheat_grading_project/Roboflow_data/Roboflow/CLAUDE/Results/03-modified-CSM-yolo112/weights/best.pt')

# Run validation specifically to see the top metrics again
metrics = best_model.val()
print(f"Best Recall: {metrics.results_dict['metrics/recall(B)']}")
# Out:
# Ultralytics 8.3.180 🚀 Python-3.10.4 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 10823MiB)
# custom-YOLO11-CSMM-SEAM summary (fused): 87 layers, 2,463,238 parameters, 0 gradients, 6.2 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3266.0±372.2 MB/s, size: 1259.1 KB)
# val: Scanning /homes/olagunju/wheat_grading_project/Roboflow_data/Roboflow/550-images-dataset/SPLIT-DATA/val/labels.cache... 110 images, 0 backgrounds, 0 corrupt: 100%|██████████| 110/110 [00:00<?, ?it/s]
# val: /homes/olagunju/wheat_grading_project/Roboflow_data/Roboflow/550-images-dataset/SPLIT-DATA/val/images/1052454_Shruken-IMG_7216.jpg: 1 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:09<00:00,  1.31s/it]
#                    all        110       4181      0.949      0.935      0.964      0.853
#                 Stones         11        104      0.971      0.971      0.985      0.867
# ...
