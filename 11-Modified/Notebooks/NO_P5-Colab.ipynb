# %%
import pandas as pd
import numpy as np

# %%
# !nvidia-smi
# Out:
# Thu Mar 26 21:05:12 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0             45W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
# Cell 1 — Run this first after every runtime restart
#!pip uninstall ultralytics -y --quiet
# !pip install -e /content/drive/MyDrive/ultralytics --quiet

# Must restart runtime after this cell — do not continue yet
print("Done — now restart runtime: Runtime → Restart session")
# Out:
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for ultralytics (pyproject.toml) ... done
# Done — now restart runtime: Runtime → Restart session

# %% [markdown]
# Restart run time session again. click on runtime on the dashboard, and restart

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive', force_remount = True)#, force_remount= True
# Out:
# Mounted at /content/drive

# %%
# Move to the folder where your dataset is located
# %cd /content/drive/MyDrive/ultralytics/ultralytics/cfg/models/11
# Out:
# /content/drive/MyDrive/ultralytics/ultralytics/cfg/models/11

# %%
# Download all modified YAML configuration files
base_url = "https://raw.githubusercontent.com/olusolaolagunju/Wheat-Grading/main/11-Modified/"
save_dir = "/content/drive/MyDrive/ultralytics/ultralytics/cfg/models/11/"

# !wget -P {save_dir} {base_url}custom-yolo11-noP5.yaml

# %%
from ultralytics import YOLO
model =YOLO("/content/drive/MyDrive/ultralytics/ultralytics/cfg/models/11/custom-yolo11-noP5.yaml")
model.info()
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# custom-YOLO11-noP5 summary: 136 layers, 1,747,664 parameters, 1,747,648 gradients, 5.6 GFLOPs
# (136, 1747664, 1747648, 5.610854400000001)

# %%
from ultralytics import YOLO

modified_model = YOLO(
   '/content/drive/MyDrive/ultralytics/ultralytics/cfg/models/11/custom-yolo11-noP5.yaml'
)

modified_model.train(
    data    = "/content/drive/MyDrive/550-images-dataset/data_config.yaml",
    epochs  = 400,
    imgsz   = 768,
    batch   = 16,
    seed    = 0,
    device  = "cuda:0",
    optimizer    = "SGD",
    lr0          = 0.01,
    momentum     = 0.937,
    weight_decay = 0.0005,
    cos_lr       = True,
    conf    = 0.25,
    iou     = 0.45,
    max_det = 500,
    fliplr    = 0.5,
    flipud    = 0.0,
    degrees   = 10.0,
    translate = 0.1,
    scale     = 0.2,
    shear     = 2.0,
    hsv_h     = 0.01,
    hsv_s     = 0.1,
    hsv_v     = 0.1,
    mosaic    = 0.4,
    copy_paste = 0.0,
    project = "/content/drive/MyDrive/550-images-dataset/Results",
    name    = "03-modified-NOP5yolo11"
)
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# Ultralytics 8.4.30 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# ...

# %%
# Load the best model from your results folder
from ultralytics import YOLO
best_model = YOLO('/content/drive/MyDrive/550-images-dataset/Results/03-modified-NOP5yolo11/weights/best.pt')

# Run validation specifically to see the top metrics again
metrics = best_model.val()
print(f"Best Recall: {metrics.results_dict['metrics/recall(B)']}")
# Out:
# Ultralytics 8.4.30 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# custom-YOLO11-noP5 summary (fused): 76 layers, 1,722,300 parameters, 0 gradients, 5.3 GFLOPs
# val: Fast image access ✅ (ping: 3.2±6.5 ms, read: 275.7±265.9 MB/s, size: 1117.4 KB)
# val: Scanning /content/drive/MyDrive/550-images-dataset/SPLIT-DATA/val/labels.cache... 110 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 110/110 33.0Mit/s 0.0s
# val: /content/drive/MyDrive/550-images-dataset/SPLIT-DATA/val/images/1052454_Shruken-IMG_7216.jpg: 1 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.4s/it 9.9s
#                    all        110       4316      0.923      0.923      0.936      0.827
#                 Stones         16        150      0.974      0.985      0.993      0.878
#                Shruken         37        744      0.965      0.902       0.94      0.835
# ...
